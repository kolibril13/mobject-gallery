# %%
from manim import *
from pathlib import Path
import shutil
import time
import json
import os
scale_res=1
scale_res=4

paramsgif = f" -v WARNING -r {170*scale_res},{170*scale_res} -i  --disable_caching Example"
params = f" -v WARNING -r {170*scale_res},{170*scale_res}  -s --disable_caching Example"

name_snippet_pairs = {}

# %%
# %%manim $paramsgif
# class Example(ZoomedScene):
#     def construct(self):
#         tex = Tex("Indicate").scale(5)
#         self.play(Indicate(tex))
#         self.wait()
# image_full_name = "inidcate.gif"
# snippet = r"""
# self.play(Indicate(tex))
# """
# name_snippet_pairs[image_full_name] = snippet
# Out:
# [09/20/21 13:30:30] WARNING  --save_as_gif is deprecated, please use           ]8;id=1632137430.7102542-328184;file:///Users/jan-hendrik/projects/manim/manim/cli/render/commands.py\commands.py]8;;\:62
#                              --format=gif instead!

# %%
# %%manim $params
# class Example(ZoomedScene):
#     def construct(self):
#         tex = Tex("Indicate").scale(5)
#         self.play(Indicate(tex))
#         self.wait()
# image_full_name = "inidcate.gif"
# name_snippet_pairs[image_full_name] = snippet

# %%
name_snippet_pairs
# Out:
# {'inidcate.gif': '\nself.play(Indicate(tex))\n'}
